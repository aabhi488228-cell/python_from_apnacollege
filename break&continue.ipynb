# %%
i = 1 
while i <= 5:
    print(i)
    i += 1
    if (i == 3 ):
        break
print("end of the loop")
# Out:
# 1
# 2
# end of the loop

# %%
list = [1,4,9,16,25,36,49,64,81,100]
x = 36
i = 0
while i<len(list):
    if (list[i] == x):
        print("found at indx",i)
        break
    else:
        print("finding....")
    i += 1
# Out:
# finding....
# finding....
# finding....
# finding....
# finding....
# found at indx 5

# %%
i = 0
while i<= 5:
    if(i == 3):
        i += 1
        continue
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
i = 0 
while i<= 10:
    if (i%2 == 0):
        i += 1
        continue
    print(i)
    i += 1
# Out:
# 1
# 3
# 5
# 7
# 9
