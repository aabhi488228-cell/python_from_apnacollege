# %%
#practice01: wap to print the length of a list
nums = [1,2,4,5]
def print_len(list):
    print(len(list))
print(len(nums))
# Out:
# 4

# %%
#practice02:wap a program to list the single element in a list
cities = ["banglore","kolar","mulbagl","chennai"]
def print_list(list):
    for item in list:
        print(item,end=" ")

print_list(cities)
# print(cities[0],end=" ")
# print(cities[1])
# Out:
# banglore kolar mulbagl chennai

# %%
#practice03:wap a program to find the factorial of n
n = 5
def cal_fact(n):\
    fact = 1
for i in range(1,n+1):
        fact *=1
print(fact)
cal_fact(5)
# Out:
# 120

# %%
#practice04:convertion of the usd to inr
def converter(usd_val):
    inr_val = usd_val*83
    print(usd_val,"USD",inr_val,"INR")
converter(100)
# Out:
# 100 USD 8300 INR

# %%
#homework
n = int(input("enetr the n"))
def comp_val(str):
    if (n%2== 0):
        print("even")
    else:
        print("odd")
comp_val(n)
# Out:
# enetr the n 9
# odd
